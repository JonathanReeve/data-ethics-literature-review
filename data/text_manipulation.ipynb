# %%
# tab -> space

inputFile = open("65.texts.txt", "r", errors="ignore") # encoding="utf8") 
exportFile = open("65texts.txt", "w")
for line in inputFile:
    new_line = line.replace('\t', ' ')
    new_line2 =ftfy.fix_text(new_line)
    print(new_line2)
    exportFile.write(new_line2) 

inputFile.close()
exportFile.close()
# Out:
# Lynch, P.J., and S. Horton. Web Style Guide: 3rd edition. Yale University Press. (On the web at http://webstyleguide.com/wsg3)
#
# Lynch/Horton, "Chapter 2: Universal Usabilityâ€, http://www.webstyleguide.com/wsg3/2-universal-usability/index.html
#
# Lynch/Horton, "Navigation and wayfinding†http://www.webstyleguide.com/wsg3/4-interface-design/2-
#
# navigation.html
#
# Lynch/Horton, "Interface designâ€. http://www.webstyleguide.com/wsg3/4-interface-design/3-interfacedesign.html
#
# Chisnell, "Usability testing demystifiedâ€. http://alistapart.com/article/usability-testing-demystified
#
# Sharma, "Pocket guide to usability testing†https://www.optimizesmart.com/pocket-guide-to-usability-testing/
#
# "Card Sorting,†http://www.usability.gov/how-to-and-tools/methods/card-sorting.html
#
# "System Usability Scale,â€https://www.usability.gov/how-to-and-tools/methods/system-usability-scale.html
#
# ...

# %%
import ftfy

# %%
ftext = ftfy.fix_text(" â€œPhone and laptop encryption guide: protect your stuff and yourself.â€ ")

# %%
ftext
# Out:
# ' "Phone and laptop encryption guide: protect your stuff and yourself.†'

# %%
fin = open("input.txt", "r") 
fout = open("output.txt", "w")
for line in fin:
   new_line = line.replace('\t', ' ')
   fout.write(new_line) 

fin.close()
fout.close()
